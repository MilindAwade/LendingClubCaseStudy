# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plot
import seaborn as sea
import datetime as dt
import warnings

# Ignoring the warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset in to df
df = pd.read_csv('loan.csv', low_memory=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
# Checking header using head() with the initial 5 rows
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
# Getting the Dimensions of the entire dataset loaded in the dataframe to get the initial idea for data analysis
# Shape() function used for dimensions
df.shape
# Out:
# (39717, 111)

# %% [markdown]
# ### Data Cleaning and Imputations

# %%
# Checking for total rows with the unique loan_status available in the df
total_rows=len(df)
total_rows
# Out:
# 39717

# %% [markdown]
# ##### Removing unwanted data

# %%
# Unique Loan status with counts
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %%
#  We can get rid off loan_status of 'CURRENT' as it serves no purpose as the loan is already granted and we may not be able to conclude in case if the customer may defaults to pay.
#  So dropping those rows 
df= df[df.loan_status != 'Current']

# Display Total Count
print("Total Rows:",len(df))
# Out:
# Total Rows: 38577

# %%
# % of rows reduced
rows_deleted=((total_rows - len(df)) * 100)/total_rows
print("% of Rows Dropped:",round(rows_deleted,2))

(df.isna().sum()/len(df.index)) * 100
# Out:
# % of Rows Dropped: 2.87
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.101097
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %%
# Checking the dimension of the dataframe 
df.shape
# Out:
# (38577, 111)

# %%
# Checking for Null values
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               38577
# total_bal_ex_mort             38577
# total_bc_limit                38577
# total_il_high_credit_limit    38577
# Length: 111, dtype: int64

# %%
#Checking for the Null value percentage
(df.isnull().sum()*100)/len(df)
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.101097
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %%
# This clearly states that we can drop Null or Missing value columns from the df, So we can drop them:
print("Columns count with NULL/Missing Values : ", len(df.columns[df.isna().all()].tolist()))
na_col=list(df.columns[df.isna().all()])
print("Null Col List:")
na_col
# Out:
# Columns count with NULL/Missing Values :  55
# Null Col List:
# ['next_pymnt_d',
#  'mths_since_last_major_derog',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_il_6m',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit']

# %%
# Dropping columns having NA 
df = df.dropna(axis = 1, how = "all")
df.shape
# Out:
# (38577, 56)

# %%
#Checking remaining columns: 
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')

# %% [markdown]
# ##### Deleting columns with value as 1 as it does not contribute in EDA

# %%
#checking dimension again
df.shape
# Out:
# (38577, 56)

# %%
for cols in df.columns:
    if df[cols].nunique(dropna=True) == 1:
        print(cols)
        df = df.drop(cols, axis=1)
# Out:
# pymnt_plan
# initial_list_status
# out_prncp
# out_prncp_inv
# collections_12_mths_ex_med
# policy_code
# application_type
# acc_now_delinq
# chargeoff_within_12_mths
# delinq_amnt
# tax_liens

# %%
df.shape
# Out:
# (38577, 45)

# %% [markdown]
# ##### Now we have 45 columns out of which some correspond to the post approval of loan
#
# - The aim is to identify patterns which indicate if a person is likely to default, which may be used for taking actions such as denying the loan, reducing the amount of loan, lending (to risky applicants) at a higher interest rate, etc.
#
# - So we can safely remove the columns which are not needed for the EDA.
#
# - Also removing those columns which doesn't contribute to identify loan defaulting such as 'id', 'member_id', 'zip_code', 'last_credit_pull_d', 'addr_state'.
#
# - Removing non contributing textual field 'url', 'title', 'emp_title', 'desc'
#
# - 'out_prncp_inv' , 'total_pymnt_inv ', etc.. are not useful contributing to the loan defaulting analysis. So removing them.

# %%
# Further dropping non contributing to EDA
non_cont_cols = ['id', 'member_id', 'url', 'desc', 'title', 'emp_title', 'sub_grade', 'delinq_2yrs', 'earliest_cr_line', 'last_pymnt_amnt','inq_last_6mths', 'open_acc', 
                 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
                 'total_pymnt','total_pymnt_inv', 'total_rec_prncp',
                 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
                 'last_pymnt_d','last_credit_pull_d','mths_since_last_delinq', 'mths_since_last_record']

df = df.drop(non_cont_cols, axis=1)

# %%
# Checking the remaining columns in dataframe
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'zip_code',
#        'addr_state', 'dti', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df.shape
# Out:
# (38577, 18)

# %% [markdown]
# # Preparing the data for analysis

# %% [markdown]
# ### Now lets check the data types and clean them as needed

# %%
df.dtypes
# Out:
# loan_amnt                 int64
# funded_amnt               int64
# funded_amnt_inv         float64
# term                     object
# int_rate                 object
# installment             float64
# grade                    object
# emp_length               object
# home_ownership           object
# annual_inc              float64
# verification_status      object
# issue_d                  object
# loan_status              object
# purpose                  object
# zip_code                 object
# addr_state               object
# dti                     float64
# pub_rec_bankruptcies    float64
# dtype: object

# %% [markdown]
# #### Checking and Cleaning/Deleting the columns as per above list

# %%
# Now Convert 'Term' from string to int
df['term'] = df['term'].apply(lambda term: int(term.strip().split()[0]))
df['term'].dtype
# Out:
# dtype('int64')

# %%
df['term'].value_counts()
# Out:
# term
# 36    29096
# 60     9481
# Name: count, dtype: int64

# %%
# Converting int_rate to float.
df['int_rate']= df['int_rate'].str.strip('%').astype(float)

# %%
df['int_rate'].value_counts()
# Out:
# int_rate
# 10.99    913
# 11.49    790
# 7.51     787
# 13.49    749
# 7.88     725
#         ...
# 17.34      1
# 16.71      1
# 16.15      1
# 18.36      1
# 14.67      1
# Name: count, Length: 370, dtype: int64

# %%
# Next-> Converting loan_funded_amnt and funded_amnt to float
df = df.assign(amnt=df['loan_amnt'].astype(float), funded_amnt=df['funded_amnt'].astype(float))
df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0           5000       5000.0           4975.0    36     10.65       162.87
# 1           2500       2500.0           2500.0    60     15.27        59.83
# 2           2400       2400.0           2400.0    36     15.96        84.33
# 3          10000      10000.0          10000.0    36     13.49       339.31
# 5           5000       5000.0           5000.0    36      7.90       156.46
# ...          ...          ...              ...   ...       ...          ...
# 39712       2500       2500.0           1075.0    36      8.07        78.42
# 39713       8500       8500.0            875.0    36     10.28       275.38
# 39714       5000       5000.0           1325.0    36      8.07       156.84
# 39715       5000       5000.0            650.0    36      7.43       155.38
# 39716       7500       7500.0            800.0    36     13.75       255.43
#
#       grade emp_length home_ownership  annual_inc verification_status issue_d  \
# 0         B  10+ years           RENT     24000.0            Verified  Dec-11
# 1         C   < 1 year           RENT     30000.0     Source Verified  Dec-11
# 2         C  10+ years           RENT     12252.0        Not Verified  Dec-11
# 3         C  10+ years           RENT     49200.0     Source Verified  Dec-11
# 5         A    3 years           RENT     36000.0     Source Verified  Dec-11
# ...     ...        ...            ...         ...                 ...     ...
# 39712     A    4 years       MORTGAGE    110000.0        Not Verified  Jul-07
# 39713     C    3 years           RENT     18000.0        Not Verified  Jul-07
# 39714     A   < 1 year       MORTGAGE    100000.0        Not Verified  Jul-07
# 39715     A   < 1 year       MORTGAGE    200000.0        Not Verified  Jul-07
# 39716     E   < 1 year            OWN     22000.0        Not Verified  Jun-07
#
#        loan_status             purpose zip_code addr_state    dti  \
# 0       Fully Paid         credit_card    860xx         AZ  27.65
# 1      Charged Off                 car    309xx         GA   1.00
# 2       Fully Paid      small_business    606xx         IL   8.72
# 3       Fully Paid               other    917xx         CA  20.00
# 5       Fully Paid             wedding    852xx         AZ  11.20
# ...            ...                 ...      ...        ...    ...
# 39712   Fully Paid    home_improvement    802xx         CO  11.33
# 39713   Fully Paid         credit_card    274xx         NC   6.40
# 39714   Fully Paid  debt_consolidation    017xx         MA   2.30
# 39715   Fully Paid               other    208xx         MD   3.72
# 39716   Fully Paid  debt_consolidation    027xx         MA  14.29
#
#        pub_rec_bankruptcies     amnt
# 0                       0.0   5000.0
# 1                       0.0   2500.0
# 2                       0.0   2400.0
# 3                       0.0  10000.0
# 5                       0.0   5000.0
# ...                     ...      ...
# 39712                   NaN   2500.0
# 39713                   NaN   8500.0
# 39714                   NaN   5000.0
# 39715                   NaN   5000.0
# 39716                   NaN   7500.0
#
# [38577 rows x 19 columns]

# %%
# check grade dattype.
df['grade'].value_counts()
# Out:
# grade
# B    11675
# A    10045
# C     7834
# D     5085
# E     2663
# F      976
# G      299
# Name: count, dtype: int64

# %%
df['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    8488
# < 1 year     4508
# 2 years      4291
# 3 years      4012
# 4 years      3342
# 5 years      3194
# 1 year       3169
# 6 years      2168
# 7 years      1711
# 8 years      1435
# 9 years      1226
# Name: count, dtype: int64

# %%
# Now, below float columns - Rounding off to 2 decimal points
for col in ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'dti']:
    df[col] = df[col].apply(lambda x: round(x,2))
    print(df[col])
# Out:
# 0         5000
# 1         2500
# 2         2400
# 3        10000
# 5         5000
#          ...
# 39712     2500
# 39713     8500
# 39714     5000
# 39715     5000
# 39716     7500
# Name: loan_amnt, Length: 38577, dtype: int64
# 0         5000.0
# 1         2500.0
# 2         2400.0
# 3        10000.0
# 5         5000.0
#           ...
# 39712     2500.0
# 39713     8500.0
# 39714     5000.0
# 39715     5000.0
# 39716     7500.0
# Name: funded_amnt, Length: 38577, dtype: float64
# 0         4975.0
# 1         2500.0
# 2         2400.0
# 3        10000.0
# 5         5000.0
#           ...
# 39712     1075.0
# 39713      875.0
# 39714     1325.0
# 39715      650.0
# 39716      800.0
# Name: funded_amnt_inv, Length: 38577, dtype: float64
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 5         7.90
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 38577, dtype: float64
# 0        27.65
# 1         1.00
# 2         8.72
# 3        20.00
# 5        11.20
#          ...
# 39712    11.33
# 39713     6.40
# 39714     2.30
# 39715     3.72
# 39716    14.29
# Name: dti, Length: 38577, dtype: float64

# %%
#Date Type conversion 
df['issue_d'] = pd.to_datetime(df.issue_d, format='%b-%y', errors='coerce')
df['issue_d']
# Out:
# 0       2011-12-01
# 1       2011-12-01
# 2       2011-12-01
# 3       2011-12-01
# 5       2011-12-01
#            ...
# 39712   2007-07-01
# 39713   2007-07-01
# 39714   2007-07-01
# 39715   2007-07-01
# 39716   2007-06-01
# Name: issue_d, Length: 38577, dtype: datetime64[ns]

# %%
(df.isnull().sum()*100)/len(df)
# Out:
# loan_amnt               0.000000
# funded_amnt             0.000000
# funded_amnt_inv         0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# emp_length              2.677761
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# zip_code                0.000000
# addr_state              0.000000
# dti                     0.000000
# pub_rec_bankruptcies    1.806776
# amnt                    0.000000
# dtype: float64

# %%
# Further filtering the NA rows for emp_length and pub_rec_bankruptcies columns as number of null rows are very less
tot_rows_bef = len(df)
df= df[df.emp_length.notna()]
df= df[df.pub_rec_bankruptcies.notna()]

# %%
df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0           5000       5000.0           4975.0    36     10.65       162.87
# 1           2500       2500.0           2500.0    60     15.27        59.83
# 2           2400       2400.0           2400.0    36     15.96        84.33
# 3          10000      10000.0          10000.0    36     13.49       339.31
# 5           5000       5000.0           5000.0    36      7.90       156.46
# ...          ...          ...              ...   ...       ...          ...
# 39562       4800       4800.0           1100.0    36     10.28       155.52
# 39573       7000       7000.0           1000.0    36     10.59       227.82
# 39623       9000       9000.0            700.0    36     12.49       301.04
# 39666      15450      15450.0            600.0    36     11.22       507.46
# 39680       3000       3000.0            525.0    36     11.86        99.44
#
#       grade emp_length home_ownership  annual_inc verification_status  \
# 0         B  10+ years           RENT     24000.0            Verified
# 1         C   < 1 year           RENT     30000.0     Source Verified
# 2         C  10+ years           RENT     12252.0        Not Verified
# 3         C  10+ years           RENT     49200.0     Source Verified
# 5         A    3 years           RENT     36000.0     Source Verified
# ...     ...        ...            ...         ...                 ...
# 39562     C     1 year           RENT     35000.0        Not Verified
# 39573     C    3 years       MORTGAGE     63500.0        Not Verified
# 39623     D    8 years       MORTGAGE     39000.0        Not Verified
# 39666     C    2 years       MORTGAGE     40000.0        Not Verified
# 39680     D    2 years       MORTGAGE     36153.0        Not Verified
#
#          issue_d  loan_status             purpose zip_code addr_state    dti  \
# 0     2011-12-01   Fully Paid         credit_card    860xx         AZ  27.65
# 1     2011-12-01  Charged Off                 car    309xx         GA   1.00
# 2     2011-12-01   Fully Paid      small_business    606xx         IL   8.72
# 3     2011-12-01   Fully Paid               other    917xx         CA  20.00
# 5     2011-12-01   Fully Paid             wedding    852xx         AZ  11.20
# ...          ...          ...                 ...      ...        ...    ...
# 39562 2007-11-01   Fully Paid  debt_consolidation    226xx         VA   7.51
# 39573 2007-11-01   Fully Paid  debt_consolidation    853xx         AZ   8.50
# 39623 2007-10-01  Charged Off  debt_consolidation    207xx         MD   5.08
# 39666 2007-08-01  Charged Off  debt_consolidation    201xx         VA  13.50
# 39680 2007-08-01   Fully Paid  debt_consolidation    479xx         IN   7.47
#
#        pub_rec_bankruptcies     amnt
# 0                       0.0   5000.0
# 1                       0.0   2500.0
# 2                       0.0   2400.0
# 3                       0.0  10000.0
# 5                       0.0   5000.0
# ...                     ...      ...
# 39562                   1.0   4800.0
# 39573                   1.0   7000.0
# 39623                   1.0   9000.0
# 39666                   1.0  15450.0
# 39680                   1.0   3000.0
#
# [36847 rows x 19 columns]

# %%
tot_del= ((tot_rows_bef-len(df))*100)/tot_rows_bef
print("% of rows Deleted:",round(tot_del,2))
df.shape
# Out:
# % of rows Deleted: 4.48
# (36847, 19)

# %%
#Final check for NA in the df

(df.isnull().sum() * 100) / len(df)
# Out:
# loan_amnt               0.0
# funded_amnt             0.0
# funded_amnt_inv         0.0
# term                    0.0
# int_rate                0.0
# installment             0.0
# grade                   0.0
# emp_length              0.0
# home_ownership          0.0
# annual_inc              0.0
# verification_status     0.0
# issue_d                 0.0
# loan_status             0.0
# purpose                 0.0
# zip_code                0.0
# addr_state              0.0
# dti                     0.0
# pub_rec_bankruptcies    0.0
# amnt                    0.0
# dtype: float64

# %%
# Now stripping the columns with string values - Years, <, + and blank spaces
df['emp_length'] = df['emp_length'].apply(lambda x: x.strip("years").strip("<").replace(" ", "").replace("+", ""))
print(df['emp_length'])
# Out:
# 0        10
# 1         1
# 2        10
# 3        10
# 5         3
#          ..
# 39562     1
# 39573     3
# 39623     8
# 39666     2
# 39680     2
# Name: emp_length, Length: 36847, dtype: object

# %% [markdown]
# ### Univariate Analysis
# ##### Finding Outliers and removing

# %% [markdown]
# #### Grouping varaibles for better understanding and analysis

# %%
# Loan Amount
df['loan_amnt_b'] = df['loan_amnt'].apply(
    lambda x: '0 - 5K' if x <= 5000 else 
              '5K - 10K' if 5000 < x <= 10000 else 
              '10K - 15K' if 10000 < x <= 15000 else 
              '15K - above'
)

# %%
# Annual Income
df['annual_inc_b'] = df['annual_inc'].apply(
    lambda x: '0 - 40k' if x <= 40000 else
              '40k - 50k' if 40000 < x <= 50000 else
              '50k to 60k' if 50000 < x <= 60000 else
              '60k to 70k' if 60000 < x <= 70000 else
              '70k to 80k' if 70000 < x <= 80000 else
              '80k - above'
)

# %%
# Interest Rate

df['int_rate_b'] = df['int_rate'].apply(
    lambda x: 'Very Low' if x <= 9 else
              'Low' if 9 < x <= 11 else
              'Moderate' if 11 < x <= 13 else
              'High' if 13 < x <= 15 else
              'Very High'
)

# %%
# dti
df['dti_b'] = df['dti'].apply(
    lambda x: 'Very Low' if x <= 8 else
              'Low' if 8 < x <= 12 else
              'Moderate' if 12 < x <= 16 else
              'High' if 16 < x <= 20 else
              'Very High'
)

# %%
# Column metadata used by functions below
column_titles = {
    'loan_amnt': 'Loan Amount',
    'term': 'Loan Term',
    'int_rate': 'Interest Rate',
    'grade': 'Grade',
    'emp_length': 'Employment Length',
    'home_ownership': 'Home Owner Status',
    'annual_inc': 'Annual Income',
    'verification_status': 'Verification Status',
    'issue_d': 'Issue Date',
    'loan_status': 'Loan Status',
    'purpose': 'Purpose of Loan',
    'addr_state': 'State',
    'dti': 'Debt To Income Ratio',
    'pub_rec_bankruptcies': 'Bankruptcies Record',
    'issue_y': 'Issue Year',
    'issue_m': 'Issue Month',
    'issue_q': 'Issue Quarter',
    'loan_amnt_b': 'Loan Amount Bins',
    'funded_amnt_inv_b': 'Investor Funded Bins',
    'funded_amnt_b': 'Funded Amount Bins',
    'annual_inc_b': 'Annual Income Bins',
    'int_rate_b': 'Interest Rate Bins',
    'dti_b': 'DTI Bins'
}

# %%
# Creating a function to generate graph
def plot_graph(dfrm, column):
    fig, p = plot.subplots(1,2, figsize=(16, 4))
    sea.distplot(dfrm.loc[dfrm[column].notnull(), column], kde=True, hist=True, ax=p[0])
    sea.boxplot(x=column, data=dfrm, ax=p[1])
    p[0].set_xlabel(column_titles[column])
    p[1].set_xlabel(column_titles[column])
    plot.tight_layout()
    plot.show()

# %%
plot.boxplot(df['loan_amnt'])
plot.show()

# %%
plot.boxplot(df['annual_inc'])
plot.show()

# %%
plot.boxplot(df['int_rate'])
plot.show()

# %%
plot.boxplot(df['dti'])
plot.show()

# %%
# As we can see that outliers exists for the columns -> 'loan_amnt', 'int_rate', 'installment', 'annual_inc'
# Let us remove the outlier:->

outliers_cols = ['loan_amnt','annual_inc', 'int_rate','dti']
# Define a function to remove outliers based on IQR
def remove_outliers_iqr(data, columns,threshold):
    for col in columns:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return data

# %%
# Remove outliers from the DataFrame
df =remove_outliers_iqr(df, outliers_cols,1.5)

# %%
# Lets check the plots again for the outliers

# %%
plot.boxplot(df['loan_amnt'])
plot.show()

# %%
plot.boxplot(df['annual_inc'])
plot.show()

# %%
plot.boxplot(df['int_rate'])
plot.show()

# %%
plot.boxplot(df['dti'])
plot.show()

# %%
#Extract necessary columns which might impact the target columns i.e. Feature selection
# df=df.loc[:,('loan_amnt','term','int_rate','grade','emp_length',
              # 'home_ownership','annual_inc','issue_d','loan_status','purpose','dti')]
# df.head()

# %%
plot_graph(df, 'loan_amnt')

# describe the Loan Amount
df['loan_amnt'].describe()
# Out:
# count    33955.000000
# mean     10212.280960
# std       6237.928473
# min        500.000000
# 25%       5000.000000
# 50%       9000.000000
# 75%      14125.000000
# max      29175.000000
# Name: loan_amnt, dtype: float64

# %% [markdown]
# ### Observation:
# #### Most of the loan amount applied was in the range of 5K - 14K
# #### Max Loan amount applied was around 27K

# %%
#create new column YEAR from the existing column
df['issue_d'] = pd.to_datetime(df['issue_d'], format='%b-%y')  # Ensure issue_d is a datetime
df['year'] = df['issue_d'].dt.year
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000       5000.0           4975.0    36     10.65       162.87     B
# 1       2500       2500.0           2500.0    60     15.27        59.83     C
# 2       2400       2400.0           2400.0    36     15.96        84.33     C
# 3      10000      10000.0          10000.0    36     13.49       339.31     C
# 5       5000       5000.0           5000.0    36      7.90       156.46     A
#
#   emp_length home_ownership  annual_inc  ... zip_code addr_state    dti  \
# 0         10           RENT     24000.0  ...    860xx         AZ  27.65
# 1          1           RENT     30000.0  ...    309xx         GA   1.00
# 2         10           RENT     12252.0  ...    606xx         IL   8.72
# 3         10           RENT     49200.0  ...    917xx         CA  20.00
# 5          3           RENT     36000.0  ...    852xx         AZ  11.20
#
#   pub_rec_bankruptcies     amnt loan_amnt_b  annual_inc_b  int_rate_b  \
# 0                  0.0   5000.0      0 - 5K       0 - 40k         Low
# 1                  0.0   2500.0      0 - 5K       0 - 40k   Very High
# 2                  0.0   2400.0      0 - 5K       0 - 40k   Very High
# 3                  0.0  10000.0    5K - 10K     40k - 50k        High
# 5                  0.0   5000.0      0 - 5K       0 - 40k    Very Low
#
#        dti_b  year
# 0  Very High  2011
# 1   Very Low  2011
# 2        Low  2011
# 3       High  2011
# 5        Low  2011
#
# [5 rows x 24 columns]

# %%
#Creating a countplot to show the year wise increasing amount of loans in lending clubs

plot.figure(figsize=(8,4))
sns.set(style="whitegrid")
ax=sns.countplot(x='year',data=df)
years = ['2007','2008','2009','2010','2011']
xpos=np.arange(len(years))
ax.set(xlabel='Years', ylabel='Total Numbers of Loans',title='Year Wise Number of Loan Applicants')
plot.xticks(xpos,years)
plot.show()

# %% [markdown]
# #### Obervation -> We can see there is a Substantial growth took place between 2008-2011 in the number of loan applicants

# %%
plot_graph(df, 'annual_inc')
#print(loan_df["loan_amnt"].mean())
# describe the annual income details
df['annual_inc'].describe()
# Out:
# count     33955.000000
# mean      60314.442505
# std       26826.583214
# min        4000.000000
# 25%       40000.000000
# 50%       55200.000000
# 75%       76000.000000
# max      139500.000000
# Name: annual_inc, dtype: float64

# %% [markdown]
# #### The Annual income of most if applicants lies between 40K-75K

# %%
print("Annual Income Average is ~ :", round(df['annual_inc'].mean(),0))
# Out:
# Annual Income Average is ~ : 60314.0

# %%
plot_graph(df, 'int_rate')
df['int_rate'].describe()
# Out:
# count    33955.000000
# mean        11.831874
# std          3.593530
# min          5.420000
# 25%          8.900000
# 50%         11.710000
# 75%         14.270000
# max         22.110000
# Name: int_rate, dtype: float64

# %% [markdown]
# #### Most of the applicant's Rate Of Interest is in the range of 8%-14%
# #### Average Rate of Interest of rate is 11.7%

# %%
# Univariate analysis of DTI

plot.title('Customer Debt To Income Ratio')
plot.xlabel("DTI Ratio")
df.dti.plot.hist(color ="skyblue")
plot.show()

# %%
df['loan_status'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='loan_status'>

# %% [markdown]
# ## Categorical Variable Analysis

# %%
df.home_ownership.value_counts().plot.bar()
# Out:
# <Axes: xlabel='home_ownership'>

# %% [markdown]
# ### Majority of applicants are either living on Rent or on Mortgage

# %%
df.purpose.value_counts().plot.bar()
# Out:
# <Axes: xlabel='purpose'>

# %% [markdown]
# #### Most of the loan applicants are for debt_consolidations.

# %%
#State wise loan applicants
df['addr_state'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### The distribution of loan amount shows that the maximum loan range amount is between 5K-10K

# %% [markdown]
# #### Most of the Loan applicants are from CA

# %% [markdown]
# # Bivariate Analysis

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'zip_code',
#        'addr_state', 'dti', 'pub_rec_bankruptcies', 'amnt', 'loan_amnt_b',
#        'annual_inc_b', 'int_rate_b', 'dti_b', 'year'],
#       dtype='object')

# %%
#Bivariate Analysis on Intrest rate  against Charged off_Proportion -

ivl = df.groupby(['int_rate_b', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
ivl['Total'] = interest_vs_loan['Charged Off']+ ivl['Fully Paid']
ivl['Chargedoff_Proportion'] = interest_vs_loan['Charged Off'] / ivl['Total']
ivl.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status int_rate_b  Charged Off  Fully Paid  Total  Chargedoff_Proportion
# 3            Very High         1728        4972   6700               0.257910
# 0                 High         1004        4961   5965               0.168315
# 2             Moderate          981        5812   6793               0.144413
# 1                  Low          590        5121   5711               0.103309
# 4             Very Low          521        8265   8786               0.059299

# %%
## plotting graph
fig, ax1 = plot.subplots(figsize=(12, 8),facecolor='c')
ax1.set_title('Interest Rate vs Chargedoff Proportion',fontsize=15,color='w')
ax1=sea.barplot(x='int_rate_b', y='Chargedoff_Proportion', data=ivl)
ax1.set_xlabel('Interest Rate',fontsize=14,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=14,color = 'w')
plot.show()

# %% [markdown]
# ### Observations:
# #### interest rate less than 10% or very low has very less chances of charged off. Intrest rates are starting from minimin 5 %.
# #### interest rate more than 16% or very high has good chnaces of charged off as compared to other category intrest rates.
# #### Charged off proportion is increasing with higher intrest rates.

# %%
#Annual income against Charge off Proportion:

irvl = df.groupby(['annual_inc_b', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
irvl['Total'] = irvl['Charged Off']+ irvl['Fully Paid']
irvl['Chargedoff_Proportion'] = irvl['Charged Off'] / irvl['Total']
irvl.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status annual_inc_b  Charged Off  Fully Paid  Total  \
# 0                0 - 40k         1570        7333   8903
# 2             50k to 60k          811        4509   5320
# 1              40k - 50k          813        4623   5436
# 3             60k to 70k          498        3352   3850
# 4             70k to 80k          400        2883   3283
# 5            80k - above          732        6431   7163
#
# loan_status  Chargedoff_Proportion
# 0                         0.176345
# 2                         0.152444
# 1                         0.149558
# 3                         0.129351
# 4                         0.121840
# 5                         0.102192

# %%
# Converting above in to bar plots for the data calculated above:
fig, ax1 = plot.subplots(figsize=(10, 7),facecolor='b')
ax1.set_title('Annual Income vs Chargedoff Proportion',fontsize=13,color = 'w')
ax1=sea.barplot(x='annual_inc_b', y='Chargedoff_Proportion', data=irvl)
ax1.set_ylabel('Chargedoff Proportion',fontsize=14,color = 'b')
ax1.set_xlabel('Annual Income',fontsize=12,color='b')
plot.show()

# %% [markdown]
# ### Observations:
# #### Income range 80000+  has less chances of charged off
# #### Income range 0-20000 has high chances of charged off
# #### Notice that with increase in annual income decreases the charged off proportion

# %%
#Bivariate Analysis of Home Ownership against Charge off proportion

hovl = df.groupby(['home_ownership', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
hovl['Total'] = hovl['Charged Off']+ hovl['Fully Paid']
hovl['Chargedoff_Proportion'] = hovl['Charged Off'] / hovl['Total']
hovl.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status home_ownership  Charged Off  Fully Paid  Total  \
# 1                    OTHER           17          75     92
# 3                     RENT         2527       14437  16964
# 2                      OWN          361        2162   2523
# 0                 MORTGAGE         1919       12457  14376
#
# loan_status  Chargedoff_Proportion
# 1                         0.184783
# 3                         0.148963
# 2                         0.143084
# 0                         0.133486

# %%
## plotting graph
fig, ax1 = plot.subplots(figsize=(10, 8),facecolor='c')
ax1.set_title('Home Ownership vs Chargedoff Proportion',fontsize=14,color='w')
ax1=sea.barplot(x='home_ownership', y='Chargedoff_Proportion', data=hovl)
ax1.set_xlabel('Home Ownership',fontsize=12,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=12,color = 'w')
plot.show()

# %% [markdown]
# ### Observation:
# #### Those who are not owning the home is having high chances of loan defaults.

# %%
#Bivariate Analysis on Purpose of loan against Charge off_Proportion

pvl = df.groupby(['purpose', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
pvl['Total'] = pvl['Charged Off']+ pvl['Fully Paid']
pvl['Chargedoff_Proportion'] = pvl['Charged Off'] / pvl['Total']
pvl.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status             purpose  Charged Off  Fully Paid  Total  \
# 11               small_business          384        1063   1447
# 10             renewable_energy           16          68     84
# 3                   educational           48         239    287
# 5                         house           49         258    307
# 9                         other          539        2853   3392
# 7                       medical           95         510    605
# 8                        moving           79         433    512
# 12                     vacation           49         280    329
# 2            debt_consolidation         2387       13671  16058
# 4              home_improvement          285        2054   2339
# 0                           car          150        1227   1377
# 1                   credit_card          460        3981   4441
# 6                major_purchase          199        1728   1927
# 13                      wedding           84         766    850
#
# loan_status  Chargedoff_Proportion
# 11                        0.265377
# 10                        0.190476
# 3                         0.167247
# 5                         0.159609
# 9                         0.158903
# 7                         0.157025
# 8                         0.154297
# 12                        0.148936
# 2                         0.148649
# 4                         0.121847
# 0                         0.108932
# 1                         0.103580
# 6                         0.103269
# 13                        0.098824

# %%
fig, ax1 = plot.subplots(figsize=(9, 6),facecolor='c')
ax1.set_title('Purpose vs Chargedoff Proportion',fontsize=13,color='w')
ax1=sea.barplot(x='purpose', y='Chargedoff_Proportion', data=pvl)
ax1.set_xlabel('Purchase of Loan',fontsize=12,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=12,color = 'w')
plot.xticks(rotation=45)
plot.show()

# %% [markdown]
# ### Observation
# #### Those applicants who is having home loan is having low chances of loan defaults.
# #### Those applicants having loan for small bussiness is having high chances for loan defaults.

# %%
#Bivariate Analysis on Debt To Income against charged off:

dti_v_loan = df.groupby(['dti_b', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
dti_v_loan['Total'] = dti_v_loan['Charged Off']+ dti_v_loan['Fully Paid']
dti_v_loan['Chargedoff_Proportion'] = dti_v_loan['Charged Off'] / dti_v_loan['Total']
dti_v_loan.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status      dti_b  Charged Off  Fully Paid  Total  Chargedoff_Proportion
# 3            Very High         1060        5533   6593               0.160777
# 0                 High          972        5262   6234               0.155919
# 2             Moderate         1005        5957   6962               0.144355
# 1                  Low          820        5423   6243               0.131347
# 4             Very Low          967        6956   7923               0.122050

# %%
fig, ax1 = plot.subplots(figsize=(10, 6),facecolor='c')
ax1.set_title('Debt To Income Ratio vs Chargedoff Proportion',fontsize=14,color='w')
ax1=sea.barplot(x='dti_b', y='Chargedoff_Proportion', data=dti_v_loan)
ax1.set_xlabel('Debt To Income Ratio',fontsize=12,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=12,color = 'w')
plot.xticks(rotation=45)
plot.show()

# %% [markdown]
# ### Observation:
# #### - High DTI value  having high risk of defaults
# #### - Lower the DTO having low chances of loan defaults

# %%
# Bivariate Analysis on Bankruptcies Record against Chargedoff_Proportion -
pub_rec_bkrptc_vs_loan = df.groupby(['pub_rec_bankruptcies', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
pub_rec_bkrptc_vs_loan['Total'] = pub_rec_bkrptc_vs_loan['Charged Off']+ pub_rec_bkrptc_vs_loan['Fully Paid']
pub_rec_bkrptc_vs_loan['Chargedoff_Proportion'] = pub_rec_bkrptc_vs_loan['Charged Off'] / pub_rec_bkrptc_vs_loan['Total']
pub_rec_bkrptc_vs_loan.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status  pub_rec_bankruptcies  Charged Off  Fully Paid  Total  \
# 2                             2.0            2           3      5
# 1                             1.0          316        1151   1467
# 0                             0.0         4506       27977  32483
#
# loan_status  Chargedoff_Proportion
# 2                         0.400000
# 1                         0.215406
# 0                         0.138719

# %%
# graph
fig, ax1 = plot.subplots(figsize=(10, 8),facecolor='c')
ax1.set_title('Bankruptcies Record vs Chargedoff Proportion',fontsize=14,color='b')
ax1=sea.barplot(x='pub_rec_bankruptcies', y='Chargedoff_Proportion', data=pub_rec_bkrptc_vs_loan)
ax1.set_xlabel('Bankruptcies Record To Income Ratio',fontsize=12,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=12,color = 'w')
plot.xticks(rotation=45)
plot.show()

# %% [markdown]
# ### Observations:
# #### - Bankruptcies Record with 2 is having high impact on loan defaults
# #### - Lower the Bankruptcies lower the risk

# %%
# #Bivariate Analysis on Issues of Year  against Chargedoff_Proportion -

issue_year_vs_loan = df.groupby(['year', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
issue_year_vs_loan['Total'] = issue_year_vs_loan['Charged Off']+ issue_year_vs_loan['Fully Paid']
issue_year_vs_loan['Chargedoff_Proportion'] = issue_year_vs_loan['Charged Off'] / issue_year_vs_loan['Total']
issue_year_vs_loan.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status  year  Charged Off  Fully Paid  Total  Chargedoff_Proportion
# 0            2007            2           5      7               0.285714
# 1            2008          165         890   1055               0.156398
# 4            2011         2742       15054  17796               0.154080
# 3            2010         1351        9288  10639               0.126986
# 2            2009          564        3894   4458               0.126514

# %%
# Graph
fig, ax1 = plot.subplots(figsize=(9, 6),facecolor='c')
ax1.set_title('Issued Year  vs Chargedoff Proportion',fontsize=14,color='w')
ax1=sea.barplot(x='year', y='Chargedoff_Proportion', data=issue_year_vs_loan)
ax1.set_xlabel('Year',fontsize=12,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=12,color = 'w')
plot.xticks(rotation=45)
plot.show()

# %% [markdown]
# ### 2007 is having highest loan defaults
# ### 2009 is having lowest loan defaults

# %%
#Bivariate Analysis on Grade against Chargedoff_Proportion -

grade_vs_loan = df.groupby(['grade', 'loan_status']).loan_status.count().unstack().fillna(0).reset_index()
grade_vs_loan['Total'] = grade_vs_loan['Charged Off']+ grade_vs_loan['Fully Paid']
grade_vs_loan['Chargedoff_Proportion'] = grade_vs_loan['Charged Off'] / grade_vs_loan['Total']
grade_vs_loan.sort_values('Chargedoff_Proportion', ascending=False)
# Out:
# loan_status grade  Charged Off  Fully Paid  Total  Chargedoff_Proportion
# 6               G           59         118    177               0.333333
# 5               F          234         513    747               0.313253
# 4               E          571        1571   2142               0.266573
# 3               D          974        3505   4479               0.217459
# 2               C         1196        5788   6984               0.171249
# 1               B         1250        9136  10386               0.120354
# 0               A          540        8500   9040               0.059735

# %%
# graph
fig, ax1 = plot.subplots(figsize=(9, 6),facecolor='c')
ax1.set_title('Grade  vs Chargedoff Proportion',fontsize=14,color='w')
ax1=sea.barplot(x='grade', y='Chargedoff_Proportion', data=grade_vs_loan)
ax1.set_xlabel('Grade ',fontsize=12,color='w')
ax1.set_ylabel('Chargedoff Proportion',fontsize=12,color = 'w')
plot.show()

# %% [markdown]
# ### Observations :
# - The Loan applicants with loan Grade G is having higest Loan Defaults.
# - The Loan applicants with loan A is having lowest Loan Defaults.

# %%
# Interest Rate Vs Employee Grades:->

# %%
grade_group = df.groupby('grade')
grade_group['int_rate'].median()
# Out:
# grade
# A     7.49
# B    10.99
# C    13.49
# D    15.62
# E    17.19
# F    19.13
# G    20.48
# Name: int_rate, dtype: float64

# %%
emp_group = df.groupby('emp_length')
emp_group['loan_amnt'].median()
# Out:
# emp_length
# 1      8000.0
# 10    10000.0
# 2      8000.0
# 3      8887.5
# 4      9000.0
# 5      9000.0
# 6      9950.0
# 7     10000.0
# 8      9600.0
# 9     10000.0
# Name: loan_amnt, dtype: float64

# %%
plot.figure(figsize=(16,6))
ax1=sns.boxplot(x='grade',y='int_rate',data=df,)
ax1.set(xlabel='Grades', ylabel='Interest Rate',title='Interest Rate Vs Employee Grades')
plot.show()

# %% [markdown]
# ##### Higher the grade higher the interest rate
# ##### A Grade is having minimum interest rate, whereas G is having highest interest rate

# %%
df.columns
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000       5000.0           4975.0    36     10.65       162.87     B
# 1       2500       2500.0           2500.0    60     15.27        59.83     C
# 2       2400       2400.0           2400.0    36     15.96        84.33     C
# 3      10000      10000.0          10000.0    36     13.49       339.31     C
# 5       5000       5000.0           5000.0    36      7.90       156.46     A
#
#   emp_length home_ownership  annual_inc  ... zip_code addr_state    dti  \
# 0         10           RENT     24000.0  ...    860xx         AZ  27.65
# 1          1           RENT     30000.0  ...    309xx         GA   1.00
# 2         10           RENT     12252.0  ...    606xx         IL   8.72
# 3         10           RENT     49200.0  ...    917xx         CA  20.00
# 5          3           RENT     36000.0  ...    852xx         AZ  11.20
#
#   pub_rec_bankruptcies     amnt loan_amnt_b  annual_inc_b  int_rate_b  \
# 0                  0.0   5000.0      0 - 5K       0 - 40k         Low
# 1                  0.0   2500.0      0 - 5K       0 - 40k   Very High
# 2                  0.0   2400.0      0 - 5K       0 - 40k   Very High
# 3                  0.0  10000.0    5K - 10K     40k - 50k        High
# 5                  0.0   5000.0      0 - 5K       0 - 40k    Very Low
#
#        dti_b  year
# 0  Very High  2011
# 1   Very Low  2011
# 2        Low  2011
# 3       High  2011
# 5        Low  2011
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Correlation Analysis

# %%
# Taking data frame for finding correlation
corr_loan = df

# %%
sea.boxplot(x = 'term', y = 'loan_amnt', data=corr_loan)
# Out:
# <Axes: xlabel='term', ylabel='loan_amnt'>

# %% [markdown]
# ##### From the above graph we can see that if term is propotional to loan amount, if term increases, loan amount increases

# %%
sea.boxplot(x = 'term', y = 'int_rate', data=corr_loan)
# Out:
# <Axes: xlabel='term', ylabel='int_rate'>

# %% [markdown]
# #### Observation: If term increases, Interest rate increases
